# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly
import plotly.graph_objects as go
import gmplot
sns.set(style="whitegrid")

# %%
#load dataset
raw_df = pd.read_excel('Madison 2015 - 2018.xlsx')
# Out:
#          DOCTNMBR    ACCDDATE  NTFYHOUR REGION COUNTY MUNICIPALITY MUNITYPE  \
# 0      01L0W78HMR  06/07/2018         0     SW   DANE      MADISON        C
# 1      01L0DPGFBH  10/16/2017         9     SW   DANE      MADISON        C
# 2      01L0CMCGHH  12/18/2017        16     SW   DANE      MADISON        C
# 3         9B8HL8H  11/25/2016        18     SW   DANE      MADISON        C
# 4         9B5LX6J  05/11/2016        22     SW   DANE      MADISON        C
# 5         9BLT74N  05/26/2015         8     SW   DANE      MADISON        C
# 6         9BH151B  12/07/2015        17     SW   DANE      MADISON        C
# 7         9BJDMFW  08/12/2015         7     SW   DANE      MADISON        C
# 8         9B5NDPN  11/16/2016        16     SW   DANE      MADISON        C
# 9         9B8CW4R  07/02/2016         9     SW   DANE      MADISON        C
# 10        9B8CW4X  07/05/2016        11     SW   DANE      MADISON        C
# 11     01L03W8HL2  05/16/2017        17     SW   DANE      MADISON        C
# 12     01L05BGSFD  02/11/2017        23     SW   DANE      MADISON        C
# 13     01L0BSNQ7K  06/06/2017        22     SW   DANE      MADISON        C
# 14     01L07K4SH8  08/03/2017        16     SW   DANE      MADISON        C
# 15        9B8JBHZ  08/24/2016         8     SW   DANE      MADISON        C
# 16        9B8G3SM  12/13/2016        12     SW   DANE      MADISON        C
# 17     01L0TS2D6Z  04/20/2017         0     SW   DANE      MADISON        C
# 18        9B8C4WS  09/17/2016        21     SW   DANE      MADISON        C
# 19        9BFZ9C9  01/07/2015         6     SW   DANE      MADISON        C
# 20        9B8CW58  08/08/2016         6     SW   DANE      MADISON        C
# 21        9B8G3SG  11/18/2016         5     SW   DANE      MADISON        C
# 22     01L07GNQ6Z  02/11/2017        21     SW   DANE      MADISON        C
# 23     01L0580QCT  10/23/2018         6     SW   DANE      MADISON        C
# 24     01L03W8HL3  05/30/2017        15     SW   DANE      MADISON        C
# 25        9B5RCJC  04/22/2016        13     SW   DANE      MADISON        C
# 26        9B8573D  02/12/2016         7     SW   DANE      MADISON        C
# 27        9B8JBGW  06/02/2016        18     SW   DANE      MADISON        C
# 28        9B8K2PK  06/07/2016        15     SW   DANE      MADISON        C
# 29        9BH6CHB  07/31/2015        16     SW   DANE      MADISON        C
# ...           ...         ...       ...    ...    ...          ...      ...
# 21373     9BCSV1T  11/08/2015         5     SW   DANE      MADISON        C
# 21374  01L06XM7SS  07/19/2017        17     SW   DANE      MADISON        C
# 21375  01L04FB00P  03/16/2017        15     SW   DANE      MADISON        C
# 21376  01L0X5NC3K  01/20/2017         5     SW   DANE      MADISON        C
# 21377  01L0DJJ8WF  09/30/2017        15     SW   DANE      MADISON        C
# 21378  01L04K13DD  09/13/2017        17     SW   DANE      MADISON        C
# 21379  01L0XTDXWX  10/15/2017        18     SW   DANE      MADISON        C
# 21380  01L0D7W14K  11/24/2018        11     SW   DANE      MADISON        C
# 21381  01L0DRXHL1  10/06/2018        14     SW   DANE      MADISON        C
# 21382  01L0CGFB3W  02/16/2018        13     SW   DANE      MADISON        C
# 21383  01L04K13BL  02/11/2017        11     SW   DANE      MADISON        C
# 21384     9B7D87V  10/20/2016        14     SW   DANE      MADISON        C
# 21385  01L0WSK149  06/11/2017        11     SW   DANE      MADISON        C
# 21386  01L04FB01F  07/20/2017        15     SW   DANE      MADISON        C
# 21387  01L0713B0L  04/06/2017        14     SW   DANE      MADISON        C
# 21388  01L0CF68XJ  09/24/2017        15     SW   DANE      MADISON        C
# 21389  01L07BZLVV  02/09/2017        17     SW   DANE      MADISON        C
# 21390  01L048CTK5  04/05/2017        13     SW   DANE      MADISON        C
# 21391  01L0NMQKTW  08/19/2017        16     SW   DANE      MADISON        C
# 21392  01L048CTLJ  12/02/2017        17     SW   DANE      MADISON        C
# 21393  01L04K13DW  11/20/2017        14     SW   DANE      MADISON        C
# 21394     9BFCJB4  11/22/2015        13     SW   DANE      MADISON        C
# 21395     9B60RRM  12/31/2016         6     SW   DANE      MADISON        C
# 21396  01L0C9H5KD  07/31/2018        20     SW   DANE      MADISON        C
# 21397  01L0BK8HLG  06/17/2017         3     SW   DANE      MADISON        C
# 21398     9B7QMCT  12/13/2016        16     SW   DANE      MADISON        C
# 21399     9BLJBKZ  12/11/2015         7     SW   DANE      MADISON        C
# 21400  01L07D6N23  12/29/2017        12     SW   DANE      MADISON        C
# 21401     9B8CW4D  06/15/2016        20     SW   DANE      MADISON        C
# 21402     9BBBF61  08/10/2016         7     SW   DANE      MADISON        C
#
#        ONHWYRP ONHWYDIR ONHWY  ... POSTSPD2  AGE2 SEX2 INJSVR2 SAFETY2  \
# 0         12.0        E    12  ...      NaN   NaN  NaN     NaN     NaN
# 1         12.0        E    12  ...     55.0  23.0    F       C   SH/LP
# 2         12.0        E    12  ...     55.0  28.0    M           SH/LP
# 3         12.0        E    12  ...      NaN   NaN  NaN     NaN     NaN
# 4         12.0        E    12  ...      NaN   NaN  NaN     NaN     NaN
# 5         12.0        E    12  ...      NaN  58.0    M       B     NaN
# 6         12.0        E   NaN  ...     35.0  32.0    F           SH/LP
# 7         12.0        E   NaN  ...     55.0  43.0    F           SH/LP
# 8         12.0        E   NaN  ...     30.0  61.0    M           SH/LP
# 9         12.0        E   NaN  ...     30.0  57.0    M           SH/LP
# 10        12.0        E   NaN  ...     35.0  84.0    F       C   SH/LP
# 11        12.0        E   NaN  ...     30.0  48.0    F           SH/LP
# 12        12.0        E    12  ...     55.0  21.0    F           SH/LP
# 13        12.0        E    12  ...     55.0  42.0    M       C   SH/LP
# 14        12.0        E   NaN  ...     30.0  60.0    F           SH/LP
# 15        12.0        E    12  ...     55.0  56.0    M           SH/LP
# 16        12.0        E    12  ...      NaN   NaN  NaN     NaN     NaN
# 17        12.0        E    12  ...      NaN   NaN  NaN     NaN     NaN
# 18        12.0        E    12  ...     55.0  51.0    M       C   SH/LP
# 19        12.0        E    12  ...     55.0   0.0    N            UNKN
# 20        12.0        E    12  ...     55.0  20.0    F       B   SH/LP
# 21        12.0        E    12  ...      NaN   NaN  NaN     NaN     NaN
# 22        12.0        E    12  ...      NaN   NaN  NaN     NaN     NaN
# 23        12.0        E    12  ...     55.0  37.0    M           SH/LP
# 24        12.0        E    12  ...     77.0  61.0    F           SH/LP
# 25        12.0        E    12  ...     35.0  30.0    F           SH/LP
# 26        12.0        E    12  ...     40.0  45.0    F           SH/LP
# 27        12.0        E    12  ...     35.0  42.0    M           SH/LP
# 28        12.0        E    12  ...     30.0  47.0    M           SH/LP
# 29        12.0        E    12  ...     35.0  49.0    M           SH/LP
# ...        ...      ...   ...  ...      ...   ...  ...     ...     ...
# 21373      NaN      NaN   NaN  ...     35.0  25.0    F           SH/LP
# 21374      NaN      NaN   NaN  ...     30.0  43.0    F           SH/LP
# 21375      NaN      NaN   NaN  ...     35.0  69.0    M           SH/LP
# 21376      NaN      NaN   NaN  ...      NaN   NaN  NaN     NaN     NaN
# 21377      NaN      NaN   NaN  ...     35.0  49.0    M           SH/LP
# 21378      NaN      NaN   NaN  ...     35.0  40.0    F           SH/LP
# 21379      NaN      NaN   NaN  ...     30.0  56.0    M           SH/LP
# 21380      NaN      NaN   NaN  ...     25.0  28.0    F           SH/LP
# 21381      NaN      NaN   NaN  ...     77.0  34.0    F           SH/LP
# 21382      NaN      NaN   NaN  ...     30.0  67.0    F           SH/LP
# 21383      NaN      NaN   NaN  ...     25.0  41.0    F           SH/LP
# 21384      NaN      NaN   NaN  ...     25.0  25.0    M           SH/LP
# 21385      NaN      NaN   NaN  ...     35.0  39.0    F       C   SH/LP
# 21386      NaN      NaN   NaN  ...     35.0  29.0    F           SH/LP
# 21387      NaN      NaN   NaN  ...     35.0  31.0    F       C   SH/LP
# 21388      NaN      NaN   NaN  ...     35.0  61.0    M       B   SH/LP
# 21389      NaN      NaN   NaN  ...     25.0  66.0    M           SH/LP
# 21390      NaN      NaN   NaN  ...     35.0  32.0    M           SH/LP
# 21391      NaN      NaN   NaN  ...     10.0  69.0    M           SH/LP
# 21392      NaN      NaN   NaN  ...     35.0  25.0    M             LAP
# 21393      NaN      NaN   NaN  ...     25.0  71.0    F           SH/LP
# 21394      NaN      NaN   NaN  ...     25.0  26.0    M           SH/LP
# 21395      NaN      NaN   NaN  ...     25.0   0.0    N             NaN
# 21396      NaN      NaN   NaN  ...     25.0   NaN  NaN     NaN     NaN
# 21397      NaN      NaN   NaN  ...     25.0   NaN  NaN     NaN     NaN
# 21398      NaN      NaN   NaN  ...      NaN   NaN  NaN     NaN     NaN
# 21399      NaN      NaN   NaN  ...     77.0   0.0    N             NaN
# 21400      NaN      NaN   NaN  ...     25.0  33.0    F           SH/LP
# 21401      NaN      NaN   NaN  ...     35.0   0.0    N             NaN
# 21402      NaN      NaN   NaN  ...     25.0   0.0    N             NaN
#
#        DRVRPC2       STNM21       STNM22 WISLR_LATDECDG WISLR_LONDECDG
# 0          NaN          NaN          NaN            NaN            NaN
# 1         OTHR    346.89(1)          NaN      43.085367     -89.521539
# 2          NaN          NaN          NaN      43.087071     -89.521578
# 3          NaN          NaN          NaN      43.081270     -89.521622
# 4          NaN          NaN          NaN      43.075696     -89.522616
# 5          NaN                                43.075126     -89.522783
# 6          NaN                                43.074937     -89.522844
# 7          NaN                                43.074937     -89.522844
# 8          NaN                                43.074937     -89.522844
# 9          NaN                                43.074937     -89.522844
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
#          ...
# 21373     NaN
# 21374     NaN
# 21375     NaN
# 21376     NaN
# 21377     NaN
# 21378     NaN
# 21379     NaN
# 21380     FTY
# 21381     NaN
# 21382     FVC
# 21383     NaN
# 21384     NaN
# 21385     NaN
# 21386     NaN
# 21387     NaN
# 21388     NaN
# 21389     NaN
# 21390     NaN
# 21391     NaN
# 21392     NaN
# 21393     NaN
# 21394     FTY
# 21395     NaN
# 21396     NaN
# 21397     NaN
# 21398     NaN
# 21399     NaN
# 21400     NaN
# 21401     NaN
# 21402     NaN
# Name: DRVRPC2, Length: 21403, dtype: object

# %%
raw_df.ACCDLOC.unique()
# Out:
# array([u'N', u'I'], dtype=object)

# %%
#Check null value
raw_df.isna().sum()['DRVRPC2']
# Out:
# 18648

# %%
import gmplot
loc_na_dropped_df = raw_df.dropna(subset=['WISLR_LATDECDG', 'WISLR_LONDECDG'])
latitudes = loc_na_dropped_df['WISLR_LATDECDG']
longitudes = loc_na_dropped_df['WISLR_LONDECDG']


gmap = gmplot.GoogleMapPlotter(37.428, -122.145, 16)

gmap.plot(latitudes, longitudes, 'cornflowerblue', edge_width=10)
gmap.scatter(more_lats, more_lngs, '#3B0B39', size=40, marker=False)
gmap.scatter(marker_lats, marker_lngs, 'k', marker=True)
gmap.heatmap(heat_lats, heat_lngs)

gmap.draw("mymap.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ed733159ca76> in <module>()
#       1 import gmplot
# ----> 2 loc_na_dropped_df = raw_df.dropna(subset=['WISLR_LATDECDG', 'WISLR_LONDECDG'])
#       3 latitudes = loc_na_dropped_df['WISLR_LATDECDG']
#       4 longitudes = loc_na_dropped_df['WISLR_LONDECDG']
#       5
#
# NameError: name 'raw_df' is not defined

# %%
plotly.offline.init_notebook_mode(connected = True)
mapbox_access_token = 'pk.eyJ1IjoicnlhbnlhbmciLCJhIjoiY2swaDI5cmt0MDdpeTNkcDhwdDFmMmgwMyJ9.k-gVR4ZYPtS4YVranuGJXA'
#get data with lat and long
loc_na_dropped_df = raw_df.dropna(subset=['WISLR_LATDECDG', 'WISLR_LONDECDG'])
lat = loc_na_dropped_df['WISLR_LATDECDG']
lon = loc_na_dropped_df['WISLR_LONDECDG']
fig = go.Figure(go.Scattermapbox(lat = lat, lon = lon,
                         mode = 'markers',
                         marker = go.scattermapbox.Marker(size=3,color='rgb(0, 0, 255)'),
                         text = loc_na_dropped_df['ACCDSVR']))
fig.update_layout(title = 'Car Accident in City of Madison',
                   autosize = True,
                   hovermode = 'closest',
                   showlegend = False,
                   mapbox = dict(accesstoken = mapbox_access_token,
                                 bearing = 0,
                                 center = dict(lat = 43.07, lon = -89.43),
                                 pitch = 0,
                                 zoom = 9.5,
                                 style = 'light'))
plotly.offline.iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="560a98f3-4fc4-4ba6-8547-85ffabc49842" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("560a98f3-4fc4-4ba6-8547-85ffabc49842")) {
#                     Plotly.newPlot(
#                         '560a98f3-4fc4-4ba6-8547-85ffabc49842',
#                         [{"lat": [43.085367028, 43.087070711, 43.0812698, 43.075696, 43.0751259, 43.0749366, 43.0749366, 43.0749366, 43.0749366, 43.0749366, 43.0749368, 43.07495201, 43.074946654, 43.0731053, 43.0682898, 43.06807586, 43.0676129, 43.0651303, 43.0649044, 43.0627688, 43.062139865, 43.061144743, 43.060464525, 43.0607235, 43.0607235, 43.0607235, 43.0607235, 43.0607235, 43.060612078, 43.060612172, 43.060
 43.0458279, 43.0458279, 43.0458279, 43.0458279, 43.0457291, 43.0452617, 43.0450559, 43.0450559, 43.0454203, 43.0454203, 43.045136843, 43.0453172, 43.0452109, 43.0451044, 43.045547611, 43.0446111, 43.045217896, 43.0445253, 43.044891094, 43.04897644, 43.044373, 43.0443023, 43.044984421, 43.0443023, 43.0443023, 43.0443023, 43.0443023, 43.0440197, 43.042121594, 43.0438783, 43.043395711, 43.0429838, 43.04258875, 43.042665049, 43.0423264, 43.042272893, 43.0421937, 43.0421937, 43.042106269, 43.041448082, 43.041589101, 43.041346684, 43.041563846, 43.041563846, 43.0413985, 43.04101701, 43.040754139, 43.0408706, 43.04014199, 43.040287648, 43.039453452, ...

# %% [markdown]
# When we zoom in the figure, it is clearly that red dots cluster in intersection areas, especially intersection of highways. Also, highway entrance and exit are the places where car crash happened a lot. And lots of red dots cluster in madison downtown which may indicate a possitive relation between car accident and car/pedestrian flow.

# %%
LOC_SVR = raw_df.groupby(['ACCDLOC','ACCDSVR']).count()['DOCTNMBR'].to_frame().reset_index()
sns.set(font_scale=1)
LOC_SVR_plot = sns.barplot(x='ACCDLOC', y='DOCTNMBR', hue='ACCDSVR', data=LOC_SVR, palette = 'bright')
LOC_SVR_leg = LOC_SVR_plot.get_legend_handles_labels()[0]
LOC_SVR_plot.legend(LOC_SVR_leg, ['FAT', 'INJ', 'PD'], title='Severity')
for patch in LOC_SVR_plot.patches:
    cnt = patch.get_height()
    LOC_SVR_plot.text(patch.get_x() + patch.get_width()/2.,cnt + 3,s = int(cnt), ha="center") 
LOC_SVR_plot.set_title('Number of Accd grouping by location and severity', fontsize = 12)
LOC_SVR_plot.set_xlabel('Location', fontsize = 12)
LOC_SVR_plot.set_ylabel('Num of Accd', fontsize = 12)
# Out:
# Text(0,0.5,'Num of Accd')

# %%
# Import gmplot library.
from gmplot import *
#Set different latitude and longitude points
Charminar_top_attraction_lats, Charminar_top_attraction_lons = zip(*[
   (43.073207, -89.37674),(43.073207, -89.497674),(43.083207, -89.397674)])
#declare the center of the map, and how much we want the map zoomed in
gmap3 = gmplot.GoogleMapPlotter(43.073207, -89.397674, 13)
# Scatter map
gmap3.scatter( Charminar_top_attraction_lats, Charminar_top_attraction_lons, '#FF0000',size = 50, marker = False )
# Location where you want to save your file.
gmap.apikey = "AIzaSyBxDbRXvpObLuZDic6a1mbRiIr-FTnXLew"

gmap3.draw( "C:\\Users\\Mark Ji\\Desktop\\map11.html" )

# %%
# Import gmplot library.
from gmplot import *
# Place map
# First two arugments are the geogrphical coordinates .i.e. Latitude and Longitude
#and the zoom resolution.
gmap=gmplot.GoogleMapPlotter(17.438139, 78.39583, 18)
# Because google maps is not a free service now, you need to get an api key. Else commenting
# below line you will see the maps with "For Development Purpose Only" on the screen and maps
# with low resolution.
#gmap.apikey = "Your_API_KEY"
gmap.apikey = "AIzaSyBxDbRXvpObLuZDic6a1mbRiIr-FTnXLew"
# Location where you want to save your file.
gmap.draw( "C:\\Users\\Mark Ji\\Desktop\\map.html" )
